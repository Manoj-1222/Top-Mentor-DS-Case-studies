# %%
import os
import sys
print(sys.version)
# Out:
# 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _testconsole        gettext             random
# PIL                 _testimportmultiple glob                re
# __future__          _testinternalcapi   graphlib            reprlib
# __hello__           _testlimitedcapi    gzip                rlcompleter
# __phello__          _testmultiphase     hashlib             runpy
# _abc                _testsinglephase    heapq               sched
# _aix_support        _thread             hmac                scipy
# _android_support    _threading_local    html                seaborn
# _apple_support      _tkinter            http                secrets
# _ast                _tokenize           idlelib             select
# _asyncio            _tracemalloc        imaplib             selectors
# _bisect             _typing             importlib           shelve
# _blake2             _uuid               inspect             shlex
# ...

# %%
import datetime
print(datetime.datetime.now().strftime('%d-%B-%Y'))
# Out:
# 14-November-2025

# %%
inp = input().split(',')
print(tuple(inp))
print(list(inp))
# Out:
# ('1', '2')
# ['1', '2']

# %%
filename = input("Enter Filename: ")
f_extension = filename.split('.')
print(f"The Extension of file is {f_extension[-1]}")
# Out:
# The Extension of file is py

# %%
print(repr(filename))
# Out:
# 'app.py'

# %%
color_list = ["Red","Green","White" ,"Black"]
print(f"{color_list[0]},{color_list[-1]}")
# Out:
# Red,Black

# %%
# volume of sphere
import math
radius = int(input("Enter Radius: "))
volume = (4/3)*math.pi *(radius**3)
print(f"Volume of sphere with radius {radius} is {volume}")
# Out:
# Volume of sphere with radius 5 is 523.5987755982989

# %%
time = float(input('Enter time in seconds: '))
day = time //(24*3600)
time = time % (24*3600)
hour = time // 3600
time %= 3600
minutes = time //60
time %= 60
seconds = time
print(f"Time is {day}:{hour}:{minutes}:{seconds}")
# Out:
# Time is 909.0:5.0:1.0:35.0
